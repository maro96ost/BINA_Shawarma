# %% [markdown]
# # 1. Bibliotheken laden

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 2. Daten laden

# %%
# CSV laden und DataFrame 'df' kreieren
df = pd.read_csv('AutoScout24_3172.csv')

# %% [markdown]
# # 3. Datensatz bereinigen

# %%
# Spalten anzeigen
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Car, Price, Date, Km, Transmission, Fuel, PS, Consumption, Location]
# Index: []

# %%
# Datensatz erstmal beschreiben, 'Unnamed: 0' als einzige numerische Werte, alle anderen Spalten sind Strings
df.describe()
# Out:
#          Unnamed: 0
# count  63440.000000
# mean   31719.500000
# std    18313.694876
# min        0.000000
# 25%    15859.750000
# 50%    31719.500000
# 75%    47579.250000
# max    63439.000000

# %%
# 'Unnamed: 0' löschen, inplace=True verändert das 'df' permanent
df.drop("Unnamed: 0", axis=1, inplace=True)

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [Car, Price, Date, Km, Transmission, Fuel, PS, Consumption, Location]
# Index: []

# %%
# Erste 5 Zeilen anzeigen
df.head()
# Out:
#                                                  Car          Price  \
# 0  MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...   CHF 18'799.–
# 1                          AUDI RS e-tron GT quattro  CHF 155'990.–
# 2                         BMW 120d xDrive Sport Line   CHF 36'900.–
# 3                 SEAT Leon ST 2.0 TSI Cupra 290 DSG   CHF 21'900.–
# 4              MERCEDES-BENZ B 250 e AMG Line 8G-DCT   CHF 37'900.–
#
#              Date         Km                Transmission  \
# 0         05.2012  68'200 km                     Automat
# 1  Neues Fahrzeug       9 km           Automatikgetriebe
# 2         05.2023  28'100 km                     Automat
# 3         03.2016  86'000 km  Halbautomatisches Getriebe
# 4         11.2020   9'500 km  Halbautomatisches Getriebe
#
#                             Fuel               PS   Consumption  \
# 0                         Diesel  204 PS (150 kW)  6.5 l/100 km
# 1                        Elektro  599 PS (440 kW)        469 km
# 2                         Diesel  190 PS (140 kW)  5.2 l/100 km
# 3                         Benzin  290 PS (213 kW)  6.6 l/100 km
# 4  Plug-in hybrid Benzin/Elektro  217 PS (160 kW)  1.5 l/100 km
#
#                Location
# 0        8156 Oberhasli
# 1            4147 Aesch
# 2             7000 Chur
# 3  5417 Untersiggenthal
# 4     6438 Ibach-Schwyz

# %%
# Preise säubern
df['Price'] = df['Price'].str.replace('CHF ', '', regex=False).str.replace("'", '', regex=False).str.rstrip('.–')

# %%
# Km säubern
df['Km'] = df['Km'].str.replace("'", "").str.replace(" km", "", regex=False)

# %%
# Non-numerische Werte in df['Km'] finden
non_numeric_km = df[~df['Km'].str.contains('^[0-9]+$', na=False)]

# %%
# Zeile mit non-numerischen Werten in df['Km'] anzeigen
non_numeric_km
# Out:
#                       Car  Price            Date Km       Transmission  \
# 46793  HONDA Ny1 Elegance  31900  Neues Fahrzeug  -  Automatikgetriebe
#
#           Fuel               PS Consumption               Location
# 46793  Elektro  204 PS (150 kW)      412 km  1214 Vernier / Genève

# %%
# Alle Werte in df['Km'] mit '- ersetzen'
df['Km'] = df['Km'].str.replace("-", "").str.replace(" km", "", regex=False)

# %%
# Erste Zeile des DataFrames anzeigen
df.head(1)
# Out:
#                                                  Car  Price     Date     Km  \
# 0  MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...  18799  05.2012  68200
#
#   Transmission    Fuel               PS   Consumption        Location
# 0      Automat  Diesel  204 PS (150 kW)  6.5 l/100 km  8156 Oberhasli

# %%
# PS und kW splitten
df[['PS', 'kW']] = df['PS'].str.extract(r'(\d+) PS \((\d+) kW\)')

# %%
df.head()
# Out:
#                                                  Car   Price            Date  \
# 0  MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...   18799         05.2012
# 1                          AUDI RS e-tron GT quattro  155990  Neues Fahrzeug
# 2                         BMW 120d xDrive Sport Line   36900         05.2023
# 3                 SEAT Leon ST 2.0 TSI Cupra 290 DSG   21900         03.2016
# 4              MERCEDES-BENZ B 250 e AMG Line 8G-DCT   37900         11.2020
#
#       Km                Transmission                           Fuel   PS  \
# 0  68200                     Automat                         Diesel  204
# 1      9           Automatikgetriebe                        Elektro  599
# 2  28100                     Automat                         Diesel  190
# 3  86000  Halbautomatisches Getriebe                         Benzin  290
# 4   9500  Halbautomatisches Getriebe  Plug-in hybrid Benzin/Elektro  217
#
#     Consumption              Location   kW
# 0  6.5 l/100 km        8156 Oberhasli  150
# 1        469 km            4147 Aesch  440
# 2  5.2 l/100 km             7000 Chur  140
# 3  6.6 l/100 km  5417 Untersiggenthal  213
# 4  1.5 l/100 km     6438 Ibach-Schwyz  160

# %%
# Neues Fahrzeug & 
#df['Date'] = df['Date'].str.replace('Neues Fahrzeug', '03.2024', regex=False) # auf 07.2024 erhöhen
df['Date'] = df['Date'].str.replace('Vorführmodell', '01.2023', regex=False)

# Alle Werte mit Format YYYY mit 01. ergänzen
df['Date'] = df['Date'].apply(lambda x: '01.' + x if len(x) == 4 and x.isdigit() else x)

# df['Date'] in Datentypen 'datetime' umwandeln
df['Date'] = pd.to_datetime(df['Date'], format='%m.%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 9
#       6 df['Date'] = df['Date'].apply(lambda x: '01.' + x if len(x) == 4 and x.isdigit() else x)
#       8 # df['Date'] in Datentypen 'datetime' umwandeln
# ----> 9 df['Date'] = pd.to_datetime(df['Date'], format='%m.%Y')
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1064, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1062             result = arg.tz_localize(tz)
#    1063 elif isinstance(arg, ABCSeries):
# -> 1064     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1065     if not cache_array.empty:
#    1066         result = arg.map(cache_array)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:229, in _maybe_cache(arg, format, cache, convert_listlike)
#     227 unique_dates = unique(arg)
#     228 if len(unique_dates) < len(arg):
# --> 229     cache_dates = convert_listlike(unique_dates, format)
#     230     # GH#45319
#     231     try:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:430, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     427         format = None
#     429 if format is not None:
# --> 430     res = _to_datetime_with_format(
#     431         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     432     )
#     433     if res is not None:
#     434         return res
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:538, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     535         return _box_as_indexlike(result, utc=utc, name=name)
#     537 # fallback
# --> 538 res = _array_strptime_with_fallback(
#     539     arg, name, tz, fmt, exact, errors, infer_datetime_format
#     540 )
#     541 return res
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:473, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     470 utc = tz == "utc"
#     472 try:
# --> 473     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     474 except OutOfBoundsDatetime:
#     475     if errors == "raise":
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data 'Neues Fahrzeug' does not match format '%m.%Y' (match)

# %%
# Dummy-Variable für Vorführmodelle mit Wert 1 hinzufügen
df['Vorführmodell'] = np.where(df['Date'] == 'Vorführmodell', 1, 0)

# %%
# PLZ von Location splitten
df[['PLZ', 'Location']] = df['Location'].str.extract(r'(\d{4})\s(.*)')
df['Location'] = df['Location'].str.replace(" ", "")

# %%
# Neue Spaltenordnung definieren
new_order = ['Car', 'Price', 'Date', 'Km', 'Transmission', 'Fuel', 'PS', 'kW', 'Consumption', 'PLZ', 'Location', 'Vorführmodell']
df = df[new_order]

# %%
# Alle numerisch relevanten Strings in Floats umwandeln
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df['PS'] = pd.to_numeric(df['PS'], errors='coerce')
df['kW'] = pd.to_numeric(df['kW'], errors='coerce')
df['PLZ'] = pd.to_numeric(df['PLZ'], errors='coerce')

# %%
df.head()
# Out:
#                                                  Car   Price            Date  \
# 0  MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...   18799         05.2012
# 1                          AUDI RS e-tron GT quattro  155990  Neues Fahrzeug
# 2                         BMW 120d xDrive Sport Line   36900         05.2023
# 3                 SEAT Leon ST 2.0 TSI Cupra 290 DSG   21900         03.2016
# 4              MERCEDES-BENZ B 250 e AMG Line 8G-DCT   37900         11.2020
#
#       Km                Transmission                           Fuel     PS  \
# 0  68200                     Automat                         Diesel  204.0
# 1      9           Automatikgetriebe                        Elektro  599.0
# 2  28100                     Automat                         Diesel  190.0
# 3  86000  Halbautomatisches Getriebe                         Benzin  290.0
# 4   9500  Halbautomatisches Getriebe  Plug-in hybrid Benzin/Elektro  217.0
#
#       kW   Consumption   PLZ         Location  Vorführmodell
# 0  150.0  6.5 l/100 km  8156        Oberhasli              0
# 1  440.0        469 km  4147            Aesch              0
# 2  140.0  5.2 l/100 km  7000             Chur              0
# 3  213.0  6.6 l/100 km  5417  Untersiggenthal              0
# 4  160.0  1.5 l/100 km  6438     Ibach-Schwyz              0

# %%
# Assuming df is your DataFrame
# Exclude 'Neues Fahrzeug' rows and find duplicates (keeping the first occurrence)
duplicates = df[(df.duplicated(keep='first')) & (df['Date'] != 'Neues Fahrzeug')]

# To track all duplicates including the first occurrence, we can mark all duplicates and then filter
all_duplicates_mask = df.duplicated(keep=False)  # Marks all duplicates
# Exclude 'Neues Fahrzeug' rows from this mask
all_duplicates_mask &= df['Date'] != 'Neues Fahrzeug'
# Extract all duplicates based on the mask
all_duplicates = df[all_duplicates_mask]

# Now, remove duplicates from the original DataFrame while keeping 'Neues Fahrzeug' rows unchanged
df_neues_fahrzeug = df[df['Date'] == 'Neues Fahrzeug']
df_others = df[df['Date'] != 'Neues Fahrzeug'].drop_duplicates()

# Concatenate the non-duplicate and 'Neues Fahrzeug' rows back together
final_df = pd.concat([df_neues_fahrzeug, df_others], ignore_index=True)

# all_duplicates contains all duplicates except those marked as 'Neues Fahrzeug'

# %%
all_duplicates
# Out:
#                                             Car  Price     Date     Km  \
# 229      SKODA Octavia Combi 2.0 TDI RS 4x4 DSG  36800  05.2022  31200
# 266              JEEP COMPASS 1.3 PHEV Summ AWD  48700  02.2024    100
# 626      FIAT TIPO 1.5 Hybrid DCT Station Wagon  23889  10.2023     20
# 887               VW E-UP ***TOP AUSSTATTUNG***  23900  11.2023     20
# 1059              BMW 530d xDr 48VTour Pure M S  59900  12.2022  23500
# ...                                         ...    ...      ...    ...
# 62684  FIAT 500 1.0 N3 MildHybrid Swiss Edition  16490  02.2024     25
# 63039                         CUPRA Born 58 kWh  36900  01.2023     50
# 63055   SKODA Kamiq 1.5 TSI ACT Monte Carlo DSG  32990  04.2023     20
# 63336           FIAT 500X 1.5 Hybrid Clross DCT  21500  05.2023      8
# 63337           FIAT 500X 1.5 Hybrid Clross DCT  21500  05.2023      8
#
#                      Transmission                        Fuel     PS     kW  \
# 229    Halbautomatisches Getriebe                      Diesel  200.0  147.0
# 266             Automatikgetriebe                           -  240.0  177.0
# 626             Automatikgetriebe  Voll-Hybrid Benzin/Elektro  130.0   96.0
# 887                       Automat                     Elektro   82.0   60.0
# 1059                      Automat  Mild-Hybrid Diesel/Elektro  286.0  210.0
# ...                           ...                         ...    ...    ...
# 62684      Schaltgetriebe manuell  Mild-Hybrid Benzin/Elektro   70.0   51.0
# 63039           Automatikgetriebe                     Elektro  204.0  150.0
# 63055  Halbautomatisches Getriebe                      Benzin  150.0  110.0
# 63336           Automatikgetriebe  Mild-Hybrid Benzin/Elektro  130.0   96.0
# 63337           Automatikgetriebe  Mild-Hybrid Benzin/Elektro  130.0   96.0
#
#         Consumption   PLZ         Location  Vorführmodell
# 229    6.2 l/100 km  9320            Arbon              0
# 266    2.1 l/100 km  9300       Wittenbach              0
# 626    5.4 l/100 km  5610       Wohlen(AG)              0
# 887          225 km  8404       Winterthur              0
# 1059     6 l/100 km  8645  Rapperswil-Jona              0
# ...             ...   ...              ...            ...
# 62684  5.2 l/100 km  5032        AarauRohr              0
# 63039        427 km  9200           Gossau              0
# 63055             -  6312      Steinhausen              0
# 63336  5.7 l/100 km  8952        Schlieren              0
# 63337  5.7 l/100 km  8952        Schlieren              0
#
# [560 rows x 12 columns]

# %%
final_df
# Out:
#                                                      Car   Price  \
# 0      MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...   18799
# 1                             BMW 120d xDrive Sport Line   36900
# 2                     SEAT Leon ST 2.0 TSI Cupra 290 DSG   21900
# 3                  MERCEDES-BENZ B 250 e AMG Line 8G-DCT   37900
# 4                   FORD S-Max 2.0 TDCi 180 Titanium FPS   19700
# ...                                                  ...     ...
# 63115                            FIAT 500 1.0 Hybrid Red   18990
# 63116              MERCEDES-BENZ GLC 200 AMG Line 4MATIC   89900
# 63117                          CUPRA LEON VZ 2.0 TSI DSG   48900
# 63118            MERCEDES-BENZ GLE 300 d AMG Line 4MATIC  118900
# 63119                CUPRA LEON ST 2.0 TSI VZ DSG 4Drive   55900
#
#                  Date      Km                Transmission  \
# 0             05.2012   68200                     Automat
# 1             05.2023   28100                     Automat
# 2             03.2016   86000  Halbautomatisches Getriebe
# 3             11.2020    9500  Halbautomatisches Getriebe
# 4             03.2018  110700  Halbautomatisches Getriebe
# ...               ...     ...                         ...
# 63115  Neues Fahrzeug       1      Schaltgetriebe manuell
# 63116  Neues Fahrzeug      50           Automatikgetriebe
# 63117  Neues Fahrzeug      15           Automatikgetriebe
# 63118  Neues Fahrzeug      50           Automatikgetriebe
# 63119  Neues Fahrzeug      10           Automatikgetriebe
#
#                                 Fuel     PS     kW   Consumption   PLZ  \
# 0                             Diesel  204.0  150.0  6.5 l/100 km  8156
# 1                             Diesel  190.0  140.0  5.2 l/100 km  7000
# 2                             Benzin  290.0  213.0  6.6 l/100 km  5417
# 3      Plug-in hybrid Benzin/Elektro  217.0  160.0  1.5 l/100 km  6438
# 4                             Diesel  180.0  132.0  5.2 l/100 km  9320
# ...                              ...    ...    ...           ...   ...
# 63115     Mild-Hybrid Benzin/Elektro   70.0   52.0    6 l/100 km  8274
# 63116     Mild-Hybrid Benzin/Elektro  227.0  167.0  7.6 l/100 km  9500
# 63117                         Benzin  300.0  221.0             -  9200
# 63118     Mild-Hybrid Diesel/Elektro  290.0  213.0  7.4 l/100 km  9500
# 63119                         Benzin  310.0  228.0             -  9200
#
#               Location  Vorführmodell
# 0            Oberhasli              0
# 1                 Chur              0
# 2      Untersiggenthal              0
# 3         Ibach-Schwyz              0
# 4                Arbon              0
# ...                ...            ...
# 63115       Tägerwilen              0
# 63116              Wil              0
# 63117           Gossau              0
# 63118              Wil              0
# 63119           Gossau              0
#
# [63120 rows x 12 columns]

# %%
df
# Out:
#                                                      Car   Price  \
# 0      MERCEDES-BENZ GLK 250 CDI BlueEfficiency 4Mati...   18799
# 1                              AUDI RS e-tron GT quattro  155990
# 2                             BMW 120d xDrive Sport Line   36900
# 3                     SEAT Leon ST 2.0 TSI Cupra 290 DSG   21900
# 4                  MERCEDES-BENZ B 250 e AMG Line 8G-DCT   37900
# ...                                                  ...     ...
# 63435     LAND ROVER Range Rover Evoque 2.0 TD4 Pure AT9   22890
# 63436                 HYUNDAI Tucson 1.6 CRDi Vertex 4WD   26900
# 63437         CITROEN Grand C4 Picasso 2.0 BlueHDi Shine   13900
# 63438                  AUDI A8 4.2 FSI quattro tiptronic   15900
# 63439                                   BMW M3 CSL Coupé  149900
#
#                  Date      Km                Transmission  \
# 0             05.2012   68200                     Automat
# 1      Neues Fahrzeug       9           Automatikgetriebe
# 2             05.2023   28100                     Automat
# 3             03.2016   86000  Halbautomatisches Getriebe
# 4             11.2020    9500  Halbautomatisches Getriebe
# ...               ...     ...                         ...
# 63435         09.2018  124000                     Automat
# 63436         05.2019   67450  Halbautomatisches Getriebe
# 63437         08.2016   57000      Schaltgetriebe manuell
# 63438         11.2010  157000                     Automat
# 63439         12.2003   76119  Halbautomatisches Getriebe
#
#                                 Fuel     PS     kW    Consumption   PLZ  \
# 0                             Diesel  204.0  150.0   6.5 l/100 km  8156
# 1                            Elektro  599.0  440.0         469 km  4147
# 2                             Diesel  190.0  140.0   5.2 l/100 km  7000
# 3                             Benzin  290.0  213.0   6.6 l/100 km  5417
# 4      Plug-in hybrid Benzin/Elektro  217.0  160.0   1.5 l/100 km  6438
# ...                              ...    ...    ...            ...   ...
# 63435                         Diesel  150.0  110.0   5.1 l/100 km  6370
# 63436                         Diesel  136.0  100.0   6.6 l/100 km  8400
# 63437                         Diesel  150.0  110.0   4.1 l/100 km  8618
# 63438                         Benzin  372.0  273.0   9.5 l/100 km  8618
# 63439                         Benzin  360.0  265.0  11.9 l/100 km  1845
#
#               Location  Vorführmodell
# 0            Oberhasli              0
# 1                Aesch              0
# 2                 Chur              0
# 3      Untersiggenthal              0
# 4         Ibach-Schwyz              0
# ...                ...            ...
# 63435            Stans              0
# 63436       Winterthur              0
# 63437      OetwilamSee              0
# 63438      OetwilamSee              0
# 63439          Noville              0
#
# [63440 rows x 12 columns]

# %%
# csv exportieren
df.to_csv('AutoScout24_3172_cleaned.csv')
